# %% [markdown]
# <a href="https://colab.research.google.com/github/RenataRSBriet/ciencia-de-dados-e-sistemas-inteligentes/blob/master/intro_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
flags = pd.read_csv('/content/drive/MyDrive/Aula/MaterialApoio/flags.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#------------------------------
# (1) - Conversão dos atributos do grupo 2
#       De: Categóricos não binários
#       Para: Categóricos binários
#------------------------------
for c in flags.columns:
  if c in ['landmass', 'zone', 'language', 'religion', 'mainhue', 'topleft', 'botright']:
    dummies = pd.get_dummies(flags[c], prefix=c)
    flags = flags.join(dummies)

# %%
#--------------------------
# (2) - normalização dos atributos dos grupos 3 e 4
#       De: numeros continuos e discretos
#       Para: numeros com valores na faixa entre 0 e 1
#--------------------------

for c in flags.columns:
  if c in ['area', 'population', 'bars', 'stripes', 'colours', 'circles', 'crosses', 'saltires', 'quarters', 'sunstars']:
    c_max = max(flags[c])
    c_min = min(flags[c])
    flags[c] = (flags[c] - c_min) / (c_max - c_min)

# %%
#-------------------------------
# (3) - exclusão dos atributos indesejados
#-------------------------------
flags = flags.drop(columns=['landmass', 'zone', 'language', 'religion', 'mainhue', 'topleft', 'botright'])

# %%
#-------------------------------
# (4) - imprimir a cofiguração final de flags
#-------------------------------
# imprime as primeiras linhas
print('head(): ')
print(flags.head)
print('-------------------------')

# imprime as ultimas linhas
print('tails(): ')
print(flags.tail())
flags
# Out:
# head():
# <bound method NDFrame.head of                name      area  population  bars   stripes   colours  red  \
# 0       Afghanistan  0.028926    0.015873   0.0  0.214286  0.571429    1
# 1           Albania  0.001295    0.002976   0.0  0.000000  0.285714    1
# 2           Algeria  0.106598    0.019841   0.4  0.000000  0.285714    1
# 3    American-Samoa  0.000000    0.000000   0.0  0.000000  0.571429    1
# 4           Andorra  0.000000    0.000000   0.6  0.000000  0.285714    1
# ..              ...       ...         ...   ...       ...       ...  ...
# 189   Western-Samoa  0.000134    0.000000   0.0  0.000000  0.285714    1
# 190      Yugoslavia  0.011428    0.021825   0.0  0.214286  0.428571    1
# 191           Zaire  0.040398    0.027778   0.0  0.000000  0.428571    1
# 192          Zambia  0.033613    0.005952   0.6  0.000000  0.428571    1
# 193        Zimbabwe  0.017454    0.007937   0.0  0.500000  0.571429    1
#
# ...

# %%
flags.to_csv('/content/drive/MyDrive/Aula/MaterialApoio/flags_transformado.csv')
